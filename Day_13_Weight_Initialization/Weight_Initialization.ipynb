# %% [markdown]
# # **Weight Initialization**

# %%
import numpy as np
import pandas as pd 
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow
import keras
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, MinMaxScaler
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.compose import ColumnTransformer
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    Gender  Height (cm)  Weight (kg) Blood Pressure (s/d)  \
# 0    Male   171.148359    86.185197              151/109
# 1    Male   172.946206    79.641937              134/112
# 2  Female   155.945488    49.167058              160/101
# 3  Female   169.078298    56.017921               133/94
# 4  Female   163.758355    73.966304              170/106
#
#    Cholesterol Level (mg/dL)        BMI  Blood Glucose Level (mg/dL)  \
# 0                 259.465814  29.423017                   157.652848
# 1                 263.630292  26.626847                   118.507805
# 2                 207.846206  20.217553                   143.587550
# 3                 253.283779  19.595270                   137.448581
# 4                 236.119899  27.582078                   145.328695
#
#    Bone Density (g/cm²)  Vision Sharpness  Hearing Ability (dB)  \
# 0              0.132868          0.200000             58.786198
# 1              0.629534          0.267312             54.635270
# 2              0.473487          0.248667             54.564632
# 3              1.184315          0.513818             79.722963
# 4              0.434562          0.306864             52.479469
#
#   Physical Activity Level Smoking Status Alcohol Consumption        Diet  \
# 0                Moderate         Former                 NaN    Low-carb
# 1                     Low        Current          Occasional    Balanced
# 2                Moderate          Never                 NaN    Balanced
# 3                Moderate          Never                 NaN    Balanced
# 4                     Low         Former            Frequent  Vegetarian
#
#   Chronic Diseases Medication Use Family History  Cognitive Function  \
# 0              NaN            NaN            NaN           44.059172
# 1     Hypertension            NaN  Heart Disease           45.312298
# 2     Hypertension        Regular   Hypertension           56.246991
# 3         Diabetes     Occasional   Hypertension           55.196092
# 4              NaN            NaN            NaN           53.023379
#
#   Mental Health Status Sleep Patterns  Stress Levels  Pollution Exposure  \
# 0                 Good       Insomnia       2.797064            5.142344
# 1                 Good         Normal       9.339930            7.272720
# 2                 Poor       Insomnia       9.234637            8.500386
# 3                 Poor       Insomnia       4.693446            7.555511
# 4                 Good         Normal       4.038537            9.429097
#
#    Sun Exposure Education Level Income Level  Age (years)
# 0      7.108975             NaN       Medium           89
# 1      3.918489   Undergraduate       Medium           77
# 2      5.393408             NaN       Medium           70
# 3      2.745578             NaN          Low           52
# 4      3.878435   Undergraduate         High           79

# %%
df.shape
# Out:
# (3000, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Gender                       3000 non-null   object
#  1   Height (cm)                  3000 non-null   float64
#  2   Weight (kg)                  3000 non-null   float64
#  3   Blood Pressure (s/d)         3000 non-null   object
#  4   Cholesterol Level (mg/dL)    3000 non-null   float64
#  5   BMI                          3000 non-null   float64
#  6   Blood Glucose Level (mg/dL)  3000 non-null   float64
#  7   Bone Density (g/cm²)         3000 non-null   float64
#  8   Vision Sharpness             3000 non-null   float64
#  9   Hearing Ability (dB)         3000 non-null   float64
#  10  Physical Activity Level      3000 non-null   object
#  11  Smoking Status               3000 non-null   object
#  12  Alcohol Consumption          1799 non-null   object
#  13  Diet                         3000 non-null   object
#  14  Chronic Diseases             1701 non-null   object
#  15  Medication Use               1802 non-null   object
#  16  Family History               1549 non-null   object
#  17  Cognitive Function           3000 non-null   float64
#  18  Mental Health Status         3000 non-null   object
#  19  Sleep Patterns               3000 non-null   object
#  20  Stress Levels                3000 non-null   float64
#  21  Pollution Exposure           3000 non-null   float64
#  22  Sun Exposure                 3000 non-null   float64
#  23  Education Level              2373 non-null   object
#  24  Income Level                 3000 non-null   object
#  25  Age (years)                  3000 non-null   int64
# dtypes: float64(12), int64(1), object(13)
# memory usage: 609.5+ KB

# %%
df.isnull().sum()
# Out:
# Gender                            0
# Height (cm)                       0
# Weight (kg)                       0
# Blood Pressure (s/d)              0
# Cholesterol Level (mg/dL)         0
# BMI                               0
# Blood Glucose Level (mg/dL)       0
# Bone Density (g/cm²)              0
# Vision Sharpness                  0
# Hearing Ability (dB)              0
# Physical Activity Level           0
# Smoking Status                    0
# Alcohol Consumption            1201
# Diet                              0
# Chronic Diseases               1299
# Medication Use                 1198
# Family History                 1451
# Cognitive Function                0
# Mental Health Status              0
# Sleep Patterns                    0
# Stress Levels                     0
# Pollution Exposure                0
# Sun Exposure                      0
# Education Level                 627
# Income Level                      0
# Age (years)                       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[['Systolic', 'Diastolic']] = df['Blood Pressure (s/d)'].str.split('/', expand=True)

df['Systolic'] = pd.to_numeric(df['Systolic'])
df['Diastolic'] = pd.to_numeric(df['Diastolic'])
df.drop(columns=['Blood Pressure (s/d)'], inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['Age (years)']),
                                                    df['Age (years)'],
                                                    test_size=0.2,
                                                    random_state=1)

# %%
numerical_columns =  [1, 2, 3, 4, 5, 6, 7, 8, 16, 19, 20, 21, 24, 25]
categorical_columns = [0, 9, 10, 11, 12, 13, 14, 15, 17, 18, 22, 23]

# %%
handle_numerical = Pipeline(steps=[
    ('impute', KNNImputer(n_neighbors=11)),
    ('scale', MinMaxScaler())
])

# %%
handle_categorical = Pipeline(steps=[
    ('impute', OneHotEncoder(drop='first', handle_unknown='ignore'))
])

# %%
preprocessing = ColumnTransformer(transformers=[
    ('numerical', handle_numerical, numerical_columns),
    ('categorical', handle_categorical, categorical_columns)
])

# %%
X_train = preprocessing.fit_transform(X_train)
X_test = preprocessing.transform(X_test)

# %%
model = Sequential()

# %%
for i in range(20):
    model.add(Dense(32, activation='relu', kernel_initializer='he_uniform'))
    if i > 18:
        model.add(Dropout(0.5))
model.add(Dense(1))

# %%
model.compile(loss='mean_squared_error', optimizer=Adam(), metrics=['mean_absolute_error'])

# %%
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 21s 20ms/step - loss: 2727.5337 - mean_absolute_error: 46.7816 - val_loss: 411.7712 - val_mean_absolute_error: 17.3774
# Epoch 2/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 614.2426 - mean_absolute_error: 19.9263 - val_loss: 280.1229 - val_mean_absolute_error: 14.0687
# Epoch 3/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 400.5540 - mean_absolute_error: 16.1189 - val_loss: 129.7534 - val_mean_absolute_error: 9.3359
# Epoch 4/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 273.8796 - mean_absolute_error: 12.9169 - val_loss: 69.1881 - val_mean_absolute_error: 6.6997
# Epoch 5/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 237.9876 - mean_absolute_error: 11.9800 - val_loss: 129.9212 - val_mean_absolute_error: 9.4378
# Epoch 6/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 248.2994 - mean_absolute_error: 12.2244 - val_loss: 65.5297 - val_mean_absolute_error: 6.5405
# Epoch 7/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 247.0392 - mean_absolute_error: 11.9818 - val_loss: 55.0889 - val_mean_absolute_error: 5.9837
# Epoch 8/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 245.9658 - mean_absolute_error: 12.0170 - val_loss: 70.8638 - val_mean_absolute_error: 6.8257
# Epoch 9/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 243.1311 - mean_absolute_error: 12.1474 - val_loss: 155.4478 - val_mean_absolute_error: 10.6391
# Epoch 10/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 254.5916 - mean_absolute_error: 12.4015 - val_loss: 43.6162 - val_mean_absolute_error: 5.3443
# Epoch 11/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 255.3992 - mean_absolute_error: 12.2488 - val_loss: 43.4933 - val_mean_absolute_error: 5.2795
# Epoch 12/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 247.9400 - mean_absolute_error: 11.9622 - val_loss: 88.3981 - val_mean_absolute_error: 7.7327
# Epoch 13/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 235.4817 - mean_absolute_error: 11.5547 - val_loss: 82.2390 - val_mean_absolute_error: 7.4383
# Epoch 14/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 247.1395 - mean_absolute_error: 11.8764 - val_loss: 52.3421 - val_mean_absolute_error: 5.7381
# Epoch 15/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 249.9085 - mean_absolute_error: 12.0583 - val_loss: 42.2272 - val_mean_absolute_error: 5.1677
# Epoch 16/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 239.3301 - mean_absolute_error: 11.9156 - val_loss: 85.5419 - val_mean_absolute_error: 7.6022
# Epoch 17/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 225.8623 - mean_absolute_error: 11.5458 - val_loss: 78.3837 - val_mean_absolute_error: 7.2130
# Epoch 18/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 225.5731 - mean_absolute_error: 11.5917 - val_loss: 46.0000 - val_mean_absolute_error: 5.4275
# Epoch 19/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 237.7916 - mean_absolute_error: 11.7318 - val_loss: 37.8491 - val_mean_absolute_error: 4.9008
# Epoch 20/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 229.4047 - mean_absolute_error: 11.5124 - val_loss: 68.4020 - val_mean_absolute_error: 6.7116
# Epoch 21/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 209.1100 - mean_absolute_error: 11.1452 - val_loss: 93.0810 - val_mean_absolute_error: 7.9620
# Epoch 22/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 254.4309 - mean_absolute_error: 12.0391 - val_loss: 45.2907 - val_mean_absolute_error: 5.3447
# Epoch 23/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 237.5493 - mean_absolute_error: 11.6264 - val_loss: 44.6458 - val_mean_absolute_error: 5.3500
# Epoch 24/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 232.6980 - mean_absolute_error: 11.6558 - val_loss: 97.3627 - val_mean_absolute_error: 8.1071
# Epoch 25/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 222.5452 - mean_absolute_error: 11.4087 - val_loss: 35.2853 - val_mean_absolute_error: 4.7868
# Epoch 26/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 217.0014 - mean_absolute_error: 11.2952 - val_loss: 34.3059 - val_mean_absolute_error: 4.7313
# Epoch 27/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 219.6614 - mean_absolute_error: 11.3243 - val_loss: 81.4016 - val_mean_absolute_error: 7.3837
# Epoch 28/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 210.0534 - mean_absolute_error: 11.1249 - val_loss: 41.6036 - val_mean_absolute_error: 5.1260
# Epoch 29/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 225.9189 - mean_absolute_error: 11.5395 - val_loss: 130.0650 - val_mean_absolute_error: 9.6004
# Epoch 30/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 245.5576 - mean_absolute_error: 12.0672 - val_loss: 40.7138 - val_mean_absolute_error: 5.1548
# Epoch 31/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 236.3071 - mean_absolute_error: 11.8605 - val_loss: 53.1650 - val_mean_absolute_error: 5.8539
# Epoch 32/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 228.0113 - mean_absolute_error: 11.5279 - val_loss: 44.7667 - val_mean_absolute_error: 5.4177
# Epoch 33/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 233.5698 - mean_absolute_error: 11.6619 - val_loss: 75.8867 - val_mean_absolute_error: 7.1228
# Epoch 34/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 241.3300 - mean_absolute_error: 11.7958 - val_loss: 34.6426 - val_mean_absolute_error: 4.7275
# Epoch 35/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 215.2121 - mean_absolute_error: 11.1907 - val_loss: 90.6537 - val_mean_absolute_error: 7.8648
# Epoch 36/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 232.4112 - mean_absolute_error: 11.4931 - val_loss: 44.1138 - val_mean_absolute_error: 5.2353
# Epoch 37/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 224.8261 - mean_absolute_error: 11.1462 - val_loss: 35.4932 - val_mean_absolute_error: 4.7143
# Epoch 38/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 211.9415 - mean_absolute_error: 11.1812 - val_loss: 34.8827 - val_mean_absolute_error: 4.7007
# Epoch 39/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 232.9613 - mean_absolute_error: 11.4249 - val_loss: 34.7866 - val_mean_absolute_error: 4.6923
# Epoch 40/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 221.3379 - mean_absolute_error: 11.4164 - val_loss: 34.4354 - val_mean_absolute_error: 4.6905
# Epoch 41/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 207.4301 - mean_absolute_error: 10.9798 - val_loss: 43.2970 - val_mean_absolute_error: 5.3153
# Epoch 42/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 219.8700 - mean_absolute_error: 11.2948 - val_loss: 69.1854 - val_mean_absolute_error: 6.8131
# Epoch 43/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 239.2661 - mean_absolute_error: 11.6651 - val_loss: 97.4494 - val_mean_absolute_error: 8.2191
# Epoch 44/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 225.2417 - mean_absolute_error: 11.4637 - val_loss: 78.7940 - val_mean_absolute_error: 7.3047
# Epoch 45/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 201.7334 - mean_absolute_error: 10.8358 - val_loss: 39.7595 - val_mean_absolute_error: 5.0058
# Epoch 46/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 234.9574 - mean_absolute_error: 11.5344 - val_loss: 88.2020 - val_mean_absolute_error: 7.7278
# Epoch 47/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 227.4773 - mean_absolute_error: 11.4331 - val_loss: 36.2028 - val_mean_absolute_error: 4.8519
# Epoch 48/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 229.5309 - mean_absolute_error: 11.3090 - val_loss: 39.1834 - val_mean_absolute_error: 4.9472
# Epoch 49/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 209.1573 - mean_absolute_error: 11.0073 - val_loss: 34.9782 - val_mean_absolute_error: 4.8389
# Epoch 50/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 214.1220 - mean_absolute_error: 11.1829 - val_loss: 62.2780 - val_mean_absolute_error: 6.3882
# Epoch 51/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 205.9372 - mean_absolute_error: 10.9498 - val_loss: 44.5371 - val_mean_absolute_error: 5.3888
# Epoch 52/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 225.3321 - mean_absolute_error: 11.2825 - val_loss: 55.8560 - val_mean_absolute_error: 6.0633
# Epoch 53/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 211.3120 - mean_absolute_error: 10.9398 - val_loss: 72.8307 - val_mean_absolute_error: 6.9935
# Epoch 54/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 208.1156 - mean_absolute_error: 11.1142 - val_loss: 76.3034 - val_mean_absolute_error: 7.1622
# Epoch 55/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 186.5729 - mean_absolute_error: 10.5411 - val_loss: 43.9410 - val_mean_absolute_error: 5.3305
# Epoch 56/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 199.3328 - mean_absolute_error: 10.8395 - val_loss: 33.6056 - val_mean_absolute_error: 4.6312
# Epoch 57/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 206.2283 - mean_absolute_error: 10.8255 - val_loss: 34.8445 - val_mean_absolute_error: 4.7544
# Epoch 58/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 220.9992 - mean_absolute_error: 11.2578 - val_loss: 35.5660 - val_mean_absolute_error: 4.7857
# Epoch 59/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 190.3579 - mean_absolute_error: 10.5768 - val_loss: 36.3481 - val_mean_absolute_error: 4.8451
# Epoch 60/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 205.6228 - mean_absolute_error: 11.0655 - val_loss: 55.9335 - val_mean_absolute_error: 6.0409
# Epoch 61/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 205.6114 - mean_absolute_error: 10.8764 - val_loss: 94.0587 - val_mean_absolute_error: 8.0378
# Epoch 62/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 201.5807 - mean_absolute_error: 10.8414 - val_loss: 34.7153 - val_mean_absolute_error: 4.7547
# Epoch 63/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 201.0046 - mean_absolute_error: 10.7597 - val_loss: 40.7236 - val_mean_absolute_error: 5.1555
# Epoch 64/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 217.9859 - mean_absolute_error: 11.2118 - val_loss: 34.0038 - val_mean_absolute_error: 4.7043
# Epoch 65/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 208.8074 - mean_absolute_error: 11.1530 - val_loss: 36.4693 - val_mean_absolute_error: 4.9789
# Epoch 66/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 192.8204 - mean_absolute_error: 10.5633 - val_loss: 52.0790 - val_mean_absolute_error: 5.7970
# Epoch 67/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 218.2260 - mean_absolute_error: 11.0355 - val_loss: 48.3323 - val_mean_absolute_error: 5.6280
# Epoch 68/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 227.4372 - mean_absolute_error: 11.3194 - val_loss: 40.9472 - val_mean_absolute_error: 5.1789
# Epoch 69/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 205.9426 - mean_absolute_error: 11.0102 - val_loss: 62.9008 - val_mean_absolute_error: 6.4845
# Epoch 70/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 199.4590 - mean_absolute_error: 10.7262 - val_loss: 64.6416 - val_mean_absolute_error: 6.5527
# Epoch 71/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 199.6756 - mean_absolute_error: 10.8951 - val_loss: 34.8981 - val_mean_absolute_error: 4.7924
# Epoch 72/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 207.0912 - mean_absolute_error: 10.8091 - val_loss: 65.5718 - val_mean_absolute_error: 6.5810
# Epoch 73/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 211.8514 - mean_absolute_error: 11.0848 - val_loss: 42.2753 - val_mean_absolute_error: 5.2886
# Epoch 74/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 205.5791 - mean_absolute_error: 11.0196 - val_loss: 37.9727 - val_mean_absolute_error: 4.9110
# Epoch 75/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 191.0442 - mean_absolute_error: 10.5057 - val_loss: 34.0893 - val_mean_absolute_error: 4.6813
# Epoch 76/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 223.9172 - mean_absolute_error: 11.3721 - val_loss: 43.5471 - val_mean_absolute_error: 5.2831
# Epoch 77/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 208.6465 - mean_absolute_error: 11.0347 - val_loss: 38.7440 - val_mean_absolute_error: 4.8605
# Epoch 78/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 221.9707 - mean_absolute_error: 11.3182 - val_loss: 42.5792 - val_mean_absolute_error: 5.2102
# Epoch 79/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 211.0890 - mean_absolute_error: 11.0215 - val_loss: 93.7986 - val_mean_absolute_error: 8.0451
# Epoch 80/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 201.7721 - mean_absolute_error: 10.6539 - val_loss: 51.8461 - val_mean_absolute_error: 5.8656
# Epoch 81/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 216.3246 - mean_absolute_error: 11.0395 - val_loss: 78.5921 - val_mean_absolute_error: 7.3241
# Epoch 82/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 199.1178 - mean_absolute_error: 10.6145 - val_loss: 129.5197 - val_mean_absolute_error: 9.5630
# Epoch 83/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 205.4082 - mean_absolute_error: 10.7655 - val_loss: 56.5982 - val_mean_absolute_error: 6.1221
# Epoch 84/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 195.1073 - mean_absolute_error: 10.5881 - val_loss: 34.7365 - val_mean_absolute_error: 4.7822
# Epoch 85/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 194.2790 - mean_absolute_error: 10.6197 - val_loss: 98.6196 - val_mean_absolute_error: 8.2999
# Epoch 86/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 190.8712 - mean_absolute_error: 10.5385 - val_loss: 37.9298 - val_mean_absolute_error: 4.9712
# Epoch 87/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 216.2722 - mean_absolute_error: 11.1726 - val_loss: 34.2223 - val_mean_absolute_error: 4.7051
# Epoch 88/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 206.1204 - mean_absolute_error: 10.7214 - val_loss: 38.8042 - val_mean_absolute_error: 4.9921
# Epoch 89/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 192.7542 - mean_absolute_error: 10.4944 - val_loss: 72.6261 - val_mean_absolute_error: 7.0443
# Epoch 90/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 220.4740 - mean_absolute_error: 11.3965 - val_loss: 38.2402 - val_mean_absolute_error: 4.9153
# Epoch 91/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 194.5138 - mean_absolute_error: 10.5461 - val_loss: 40.2012 - val_mean_absolute_error: 5.0803
# Epoch 92/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 222.2928 - mean_absolute_error: 11.1340 - val_loss: 48.0106 - val_mean_absolute_error: 5.6579
# Epoch 93/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 209.2875 - mean_absolute_error: 10.9836 - val_loss: 113.4621 - val_mean_absolute_error: 8.7876
# Epoch 94/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 198.2823 - mean_absolute_error: 10.5909 - val_loss: 52.2739 - val_mean_absolute_error: 5.8604
# Epoch 95/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 187.6856 - mean_absolute_error: 10.2520 - val_loss: 48.2928 - val_mean_absolute_error: 5.4791
# Epoch 96/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 196.6705 - mean_absolute_error: 10.5914 - val_loss: 35.4380 - val_mean_absolute_error: 4.6857
# Epoch 97/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 204.9530 - mean_absolute_error: 10.7768 - val_loss: 39.7081 - val_mean_absolute_error: 5.0023
# Epoch 98/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 211.3368 - mean_absolute_error: 10.8726 - val_loss: 59.4942 - val_mean_absolute_error: 6.1625
# Epoch 99/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 202.9604 - mean_absolute_error: 10.7646 - val_loss: 38.7362 - val_mean_absolute_error: 4.9788
# Epoch 100/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 208.2852 - mean_absolute_error: 10.8934 - val_loss: 75.6728 - val_mean_absolute_error: 7.0739

# %%
y_pred = model.predict(X_test)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8219131231307983
