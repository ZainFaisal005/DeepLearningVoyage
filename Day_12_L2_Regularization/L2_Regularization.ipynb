# %% [markdown]
# # **L2 Regularization - CS Students Performance**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import tensorflow
import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, MinMaxScaler
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer
from tensorflow.keras import Sequential
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, Dropout 
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('/kaggle/input/student-performance-predictions/student_performance.csv')
df.head()
# Out:
#    StudentID     Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1     John    Male              85                 15
# 1          2    Sarah  Female              90                 20
# 2          3     Alex    Male              78                 10
# 3          4  Michael    Male              92                 25
# 4          5     Emma  Female              88                 18
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0             78                          1            High          80
# 1             85                          2          Medium          87
# 2             65                          0             Low          68
# 3             90                          3            High          92
# 4             82                          2          Medium          85

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10 non-null     int64
#  1   Name                       10 non-null     object
#  2   Gender                     10 non-null     object
#  3   AttendanceRate             10 non-null     int64
#  4   StudyHoursPerWeek          10 non-null     int64
#  5   PreviousGrade              10 non-null     int64
#  6   ExtracurricularActivities  10 non-null     int64
#  7   ParentalSupport            10 non-null     object
#  8   FinalGrade                 10 non-null     int64
# dtypes: int64(6), object(3)
# memory usage: 848.0+ bytes

# %%
df.shape
# Out:
# (10, 9)

# %%
df.columns
# Out:
# Index(['StudentID', 'Name', 'Gender', 'AttendanceRate', 'StudyHoursPerWeek',
#        'PreviousGrade', 'ExtracurricularActivities', 'ParentalSupport',
#        'FinalGrade'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# StudentID                    0
# Name                         0
# Gender                       0
# AttendanceRate               0
# StudyHoursPerWeek            0
# PreviousGrade                0
# ExtracurricularActivities    0
# ParentalSupport              0
# FinalGrade                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe(include='all')
# Out:
#         StudentID  Name Gender  AttendanceRate  StudyHoursPerWeek  \
# count    10.00000    10     10       10.000000          10.000000
# unique        NaN    10      2             NaN                NaN
# top           NaN  John   Male             NaN                NaN
# freq          NaN     1      5             NaN                NaN
# mean      5.50000   NaN    NaN       85.600000          17.700000
# std       3.02765   NaN    NaN        7.441625           6.848357
# min       1.00000   NaN    NaN       70.000000           8.000000
# 25%       3.25000   NaN    NaN       82.750000          12.750000
# 50%       5.50000   NaN    NaN       86.500000          17.500000
# 75%       7.75000   NaN    NaN       90.750000          21.500000
# max      10.00000   NaN    NaN       95.000000          30.000000
#
#         PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# count       10.000000                  10.000000              10   10.000000
# unique            NaN                        NaN               3         NaN
# top               NaN                        NaN            High         NaN
# freq              NaN                        NaN               4         NaN
# mean        78.100000                   1.500000             NaN   80.200000
# std         10.170218                   1.080123             NaN   10.097304
# min         60.000000                   0.000000             NaN   62.000000
# 25%         71.750000                   1.000000             NaN   73.500000
# 50%         80.000000                   1.500000             NaN   82.500000
# 75%         85.750000                   2.000000             NaN   87.750000
# max         90.000000                   3.000000             NaN   92.000000

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['StudentID', 'Name', 'FinalGrade']),
                                                    df['FinalGrade'],
                                                    test_size=0.2,
                                                    random_state=42)

# %%
X_test.shape
# Out:
# (2, 6)

# %%
y_test.shape
# Out:
# (2,)

# %%
numerical_columns = [1, 2, 3, 4]
categorical_columns = [0, 5]

# %%
handle_numerical = Pipeline(steps=[
    ('impute', KNNImputer(n_neighbors=11)),
    ('scale', MinMaxScaler())
])

# %%
handle_categorical = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='most_frequent')),
    ('encode', OneHotEncoder(drop='first', handle_unknown='ignore'))
])

# %%
preprocessing = ColumnTransformer(transformers=[
    ('numerical', handle_numerical, numerical_columns),
    ('categorical', handle_categorical, categorical_columns)
])

# %%
model = Sequential()

# %%
model.add(Dense(X_train.shape[0], activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dense(X_train.shape[0], activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dense(X_train.shape[0], activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dense(X_train.shape[0], activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dense(X_train.shape[0], activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dense(X_train.shape[0], activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dense(X_train.shape[0], activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dense(X_train.shape[0], activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dense(X_train.shape[0], activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.3))
model.add(Dense(X_train.shape[0], activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.3))
model.add(Dense(X_train.shape[0], activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.3))
model.add(Dense(X_train.shape[0], activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.3))
model.add(Dense(X_train.shape[0], activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.3))
model.add(Dense(X_train.shape[0], activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.3))

model.add(Dense(5, activation='relu', kernel_regularizer=l2(0.01)))

# %%
model.compile(optimizer='Adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# %%
X_train = preprocessing.fit_transform(X_train)
X_test = preprocessing.transform(X_test)

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=300, validation_split=0.2)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step - loss: 6697.2891 - mean_absolute_error: 81.4996 - val_loss: 6154.8623 - val_mean_absolute_error: 76.9979
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 6696.9741 - mean_absolute_error: 81.4977 - val_loss: 6154.5762 - val_mean_absolute_error: 76.9961
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6696.6733 - mean_absolute_error: 81.4959 - val_loss: 6154.2607 - val_mean_absolute_error: 76.9941
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6696.2808 - mean_absolute_error: 81.4934 - val_loss: 6153.9634 - val_mean_absolute_error: 76.9921
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 6694.8228 - mean_absolute_error: 81.4844 - val_loss: 6153.6392 - val_mean_absolute_error: 76.9900
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6695.3726 - mean_absolute_error: 81.4875 - val_loss: 6153.3066 - val_mean_absolute_error: 76.9878
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6695.6675 - mean_absolute_error: 81.4896 - val_loss: 6152.9741 - val_mean_absolute_error: 76.9857
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6695.1934 - mean_absolute_error: 81.4870 - val_loss: 6152.6440 - val_mean_absolute_error: 76.9836
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 6695.4546 - mean_absolute_error: 81.4886 - val_loss: 6152.3164 - val_mean_absolute_error: 76.9814
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6694.4409 - mean_absolute_error: 81.4825 - val_loss: 6151.9775 - val_mean_absolute_error: 76.9793
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 6693.5610 - mean_absolute_error: 81.4767 - val_loss: 6151.6274 - val_mean_absolute_error: 76.9770
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6694.8770 - mean_absolute_error: 81.4851 - val_loss: 6151.2910 - val_mean_absolute_error: 76.9748
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 6693.6470 - mean_absolute_error: 81.4773 - val_loss: 6150.9565 - val_mean_absolute_error: 76.9727
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6692.6265 - mean_absolute_error: 81.4719 - val_loss: 6150.6123 - val_mean_absolute_error: 76.9704
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 6693.8599 - mean_absolute_error: 81.4783 - val_loss: 6150.2725 - val_mean_absolute_error: 76.9682
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 6689.6929 - mean_absolute_error: 81.4520 - val_loss: 6149.9082 - val_mean_absolute_error: 76.9659
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6690.6206 - mean_absolute_error: 81.4591 - val_loss: 6149.5264 - val_mean_absolute_error: 76.9634
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6690.1382 - mean_absolute_error: 81.4561 - val_loss: 6149.1270 - val_mean_absolute_error: 76.9608
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6691.9888 - mean_absolute_error: 81.4684 - val_loss: 6148.7217 - val_mean_absolute_error: 76.9582
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6689.4180 - mean_absolute_error: 81.4485 - val_loss: 6148.3066 - val_mean_absolute_error: 76.9555
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 6687.8242 - mean_absolute_error: 81.4427 - val_loss: 6147.8765 - val_mean_absolute_error: 76.9528
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 6688.2896 - mean_absolute_error: 81.4447 - val_loss: 6147.4331 - val_mean_absolute_error: 76.9499
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6690.3027 - mean_absolute_error: 81.4560 - val_loss: 6146.9907 - val_mean_absolute_error: 76.9470
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6688.3027 - mean_absolute_error: 81.4449 - val_loss: 6146.5430 - val_mean_absolute_error: 76.9441
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 6688.3579 - mean_absolute_error: 81.4454 - val_loss: 6146.0835 - val_mean_absolute_error: 76.9411
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 6687.6362 - mean_absolute_error: 81.4415 - val_loss: 6145.6216 - val_mean_absolute_error: 76.9381
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 6686.6147 - mean_absolute_error: 81.4333 - val_loss: 6145.1504 - val_mean_absolute_error: 76.9351
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6680.9946 - mean_absolute_error: 81.3970 - val_loss: 6144.6479 - val_mean_absolute_error: 76.9318
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6688.4272 - mean_absolute_error: 81.4469 - val_loss: 6144.1484 - val_mean_absolute_error: 76.9286
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6686.8774 - mean_absolute_error: 81.4353 - val_loss: 6143.6304 - val_mean_absolute_error: 76.9252
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6683.4663 - mean_absolute_error: 81.4159 - val_loss: 6143.0845 - val_mean_absolute_error: 76.9217
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6684.8218 - mean_absolute_error: 81.4254 - val_loss: 6142.5361 - val_mean_absolute_error: 76.9181
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 6681.2905 - mean_absolute_error: 81.4062 - val_loss: 6141.9634 - val_mean_absolute_error: 76.9144
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 6687.6167 - mean_absolute_error: 81.4408 - val_loss: 6141.3896 - val_mean_absolute_error: 76.9106
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6683.2397 - mean_absolute_error: 81.4106 - val_loss: 6140.7993 - val_mean_absolute_error: 76.9068
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 6680.9448 - mean_absolute_error: 81.4024 - val_loss: 6140.1948 - val_mean_absolute_error: 76.9029
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6679.9116 - mean_absolute_error: 81.3920 - val_loss: 6139.5654 - val_mean_absolute_error: 76.8988
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6680.8735 - mean_absolute_error: 81.4001 - val_loss: 6138.9082 - val_mean_absolute_error: 76.8945
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6681.5405 - mean_absolute_error: 81.4056 - val_loss: 6138.2339 - val_mean_absolute_error: 76.8901
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 6683.8218 - mean_absolute_error: 81.4185 - val_loss: 6137.5547 - val_mean_absolute_error: 76.8857
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 6677.2046 - mean_absolute_error: 81.3795 - val_loss: 6136.8315 - val_mean_absolute_error: 76.8810
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 6680.7886 - mean_absolute_error: 81.3987 - val_loss: 6136.0811 - val_mean_absolute_error: 76.8761
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6677.7676 - mean_absolute_error: 81.3789 - val_loss: 6135.2959 - val_mean_absolute_error: 76.8710
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6679.1362 - mean_absolute_error: 81.3894 - val_loss: 6134.5088 - val_mean_absolute_error: 76.8659
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6672.9146 - mean_absolute_error: 81.3413 - val_loss: 6133.6582 - val_mean_absolute_error: 76.8603
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 6674.6421 - mean_absolute_error: 81.3611 - val_loss: 6132.7715 - val_mean_absolute_error: 76.8545
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 6672.3022 - mean_absolute_error: 81.3440 - val_loss: 6131.8330 - val_mean_absolute_error: 76.8484
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 6672.3862 - mean_absolute_error: 81.3528 - val_loss: 6130.8423 - val_mean_absolute_error: 76.8419
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 6677.2720 - mean_absolute_error: 81.3786 - val_loss: 6129.8169 - val_mean_absolute_error: 76.8352
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6667.3926 - mean_absolute_error: 81.3112 - val_loss: 6128.7231 - val_mean_absolute_error: 76.8281
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6672.2964 - mean_absolute_error: 81.3487 - val_loss: 6127.5752 - val_mean_absolute_error: 76.8206
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6656.6079 - mean_absolute_error: 81.2593 - val_loss: 6126.3369 - val_mean_absolute_error: 76.8125
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6644.0757 - mean_absolute_error: 81.1689 - val_loss: 6124.9736 - val_mean_absolute_error: 76.8036
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6674.9321 - mean_absolute_error: 81.3510 - val_loss: 6123.5762 - val_mean_absolute_error: 76.7945
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6667.7017 - mean_absolute_error: 81.3175 - val_loss: 6122.1533 - val_mean_absolute_error: 76.7852
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 6662.1099 - mean_absolute_error: 81.2743 - val_loss: 6120.6333 - val_mean_absolute_error: 76.7753
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6667.7642 - mean_absolute_error: 81.3139 - val_loss: 6119.0386 - val_mean_absolute_error: 76.7648
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 6675.5645 - mean_absolute_error: 81.3689 - val_loss: 6117.4062 - val_mean_absolute_error: 76.7542
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6633.8452 - mean_absolute_error: 81.0783 - val_loss: 6115.5864 - val_mean_absolute_error: 76.7423
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6671.5845 - mean_absolute_error: 81.3438 - val_loss: 6113.7485 - val_mean_absolute_error: 76.7303
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6668.7632 - mean_absolute_error: 81.3239 - val_loss: 6111.8926 - val_mean_absolute_error: 76.7182
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 6628.8667 - mean_absolute_error: 81.0483 - val_loss: 6109.7993 - val_mean_absolute_error: 76.7045
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 6634.4824 - mean_absolute_error: 81.1061 - val_loss: 6107.4912 - val_mean_absolute_error: 76.6895
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6645.3022 - mean_absolute_error: 81.1808 - val_loss: 6105.0078 - val_mean_absolute_error: 76.6732
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 6667.3340 - mean_absolute_error: 81.3209 - val_loss: 6102.5239 - val_mean_absolute_error: 76.6570
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 6633.8320 - mean_absolute_error: 81.1278 - val_loss: 6099.8276 - val_mean_absolute_error: 76.6395
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6663.1685 - mean_absolute_error: 81.2879 - val_loss: 6097.1191 - val_mean_absolute_error: 76.6218
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6637.7739 - mean_absolute_error: 81.1417 - val_loss: 6094.1826 - val_mean_absolute_error: 76.6026
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6613.4492 - mean_absolute_error: 80.9968 - val_loss: 6090.9087 - val_mean_absolute_error: 76.5813
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 6658.8765 - mean_absolute_error: 81.2645 - val_loss: 6087.5884 - val_mean_absolute_error: 76.5596
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 6613.4414 - mean_absolute_error: 81.0015 - val_loss: 6083.9429 - val_mean_absolute_error: 76.5358
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6569.6313 - mean_absolute_error: 80.7001 - val_loss: 6079.8149 - val_mean_absolute_error: 76.5088
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6610.1929 - mean_absolute_error: 80.9259 - val_loss: 6075.2998 - val_mean_absolute_error: 76.4793
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 6623.7637 - mean_absolute_error: 81.0322 - val_loss: 6070.5308 - val_mean_absolute_error: 76.4482
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 6630.8618 - mean_absolute_error: 81.0922 - val_loss: 6065.4927 - val_mean_absolute_error: 76.4153
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6581.0894 - mean_absolute_error: 80.7450 - val_loss: 6059.9404 - val_mean_absolute_error: 76.3790
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6646.3438 - mean_absolute_error: 81.1831 - val_loss: 6054.3569 - val_mean_absolute_error: 76.3425
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 6646.5903 - mean_absolute_error: 81.1798 - val_loss: 6048.6367 - val_mean_absolute_error: 76.3051
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6602.6499 - mean_absolute_error: 80.9298 - val_loss: 6042.4453 - val_mean_absolute_error: 76.2646
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 6535.3452 - mean_absolute_error: 80.4376 - val_loss: 6035.4126 - val_mean_absolute_error: 76.2186
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 6435.8218 - mean_absolute_error: 79.9080 - val_loss: 6027.6099 - val_mean_absolute_error: 76.1675
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 6582.9126 - mean_absolute_error: 80.8005 - val_loss: 6019.2925 - val_mean_absolute_error: 76.1129
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6524.0562 - mean_absolute_error: 80.3038 - val_loss: 6010.1816 - val_mean_absolute_error: 76.0532
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6575.6519 - mean_absolute_error: 80.7342 - val_loss: 6000.5195 - val_mean_absolute_error: 75.9897
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 6615.1538 - mean_absolute_error: 80.9960 - val_loss: 5990.6274 - val_mean_absolute_error: 75.9247
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 6566.0005 - mean_absolute_error: 80.6182 - val_loss: 5980.0767 - val_mean_absolute_error: 75.8553
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6604.4819 - mean_absolute_error: 80.8698 - val_loss: 5969.0757 - val_mean_absolute_error: 75.7828
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 6472.8647 - mean_absolute_error: 80.0660 - val_loss: 5956.7354 - val_mean_absolute_error: 75.7014
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6446.2026 - mean_absolute_error: 79.9679 - val_loss: 5942.9751 - val_mean_absolute_error: 75.6106
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6478.8809 - mean_absolute_error: 79.9921 - val_loss: 5927.9253 - val_mean_absolute_error: 75.5112
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6616.0503 - mean_absolute_error: 80.9949 - val_loss: 5912.5718 - val_mean_absolute_error: 75.4096
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6277.8130 - mean_absolute_error: 78.8629 - val_loss: 5895.2705 - val_mean_absolute_error: 75.2950
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6424.6304 - mean_absolute_error: 79.7700 - val_loss: 5876.4546 - val_mean_absolute_error: 75.1701
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6333.3921 - mean_absolute_error: 79.0485 - val_loss: 5855.6919 - val_mean_absolute_error: 75.0320
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6215.2759 - mean_absolute_error: 78.3334 - val_loss: 5832.6479 - val_mean_absolute_error: 74.8784
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6134.8413 - mean_absolute_error: 77.9263 - val_loss: 5807.3193 - val_mean_absolute_error: 74.7092
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 6577.7329 - mean_absolute_error: 80.7662 - val_loss: 5781.5801 - val_mean_absolute_error: 74.5369
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6288.5098 - mean_absolute_error: 78.9153 - val_loss: 5753.3545 - val_mean_absolute_error: 74.3472
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 6537.5044 - mean_absolute_error: 80.5506 - val_loss: 5724.6904 - val_mean_absolute_error: 74.1541
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6569.3687 - mean_absolute_error: 80.5712 - val_loss: 5695.3916 - val_mean_absolute_error: 73.9558

# %%
y_pred = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
